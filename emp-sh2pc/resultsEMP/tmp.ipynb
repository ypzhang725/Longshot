# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(2015)

raw = (np.random.random(1000) - 0.5).cumsum()
smooth = raw.reshape(-1,10).mean(axis=1)

x1 = np.linspace(0, 1, 1000)
x2 = np.linspace(0, 0.5, 100)
plt.plot(x1, raw)
plt.plot(x2, smooth)
plt.show()

# %%
T = 200
true = [25 for i in range(T)]
leaf_list40 = []
for i in range(40):
    leaf_list = (np.random.laplace(0, (1/1), T)) + true
    leaf_list_ = [i if i >=0 else 0 for i in leaf_list]

    cdf_leaf_noise = np.array([sum(leaf_list_[ : i + 1]) for i in range(len(leaf_list_))])
    cdf_leaf_true = np.array([sum(true[ : i + 1]) for i in range(len(true))])
    leaf_error = np.abs(cdf_leaf_noise - cdf_leaf_true)
    leaf_list40.append(leaf_error)

leaf = np.sum(leaf_list40, axis = 0)


leaf = np.abs(cdf_leaf_noise - cdf_leaf_true)
baseline_list = (np.random.laplace(0, (T/1), T))
baseline = np.abs(baseline_list)
#sortD = [5, 5, 12, 13, 12, 11, 19, 25, 12, 13, 19, 22, 22, 21, 27, 38, 14, 13, 20, 23, 20, 22, 27, 35, 20, 20, 27, 30, 29, 27, 36, 59, 12, 13, 19, 25, 22, 24, 28, 36, 20, 24, 28, 31, 31, 29, 38, 52, 21, 21, 29, 32, 30, 30, 37, 46, 29, 28, 40, 39, 38, 38, 48, 78, 14, 12, 20, 23, 18, 22, 28, 34, 19, 24, 28, 30, 29, 31, 38, 49, 21, 22, 30, 33, 28, 30, 38, 46, 30, 30, 38, 44, 38, 37, 51, 65, 21, 22, 29, 32]
x1 = np.linspace(1, T, T)

#plt.scatter(x1, sortD)
plt.scatter(x1, leaf)
#plt.scatter(x1, baseline)

plt.show()
print(test_list)
print(leaf)
# Out:
# [1, 2, 3, 4]
# [2.56162107e-01 1.47453492e+00 1.94177596e-01 1.75205631e+00
#  6.95583732e-01 1.59188556e+00 2.97664159e-01 1.69327734e+00
#  2.31562895e-02 1.02048399e+00 2.56752988e+00 3.23853086e+00
#  3.83009603e+00 4.21771001e+00 2.19091470e+00 5.11542627e+00
#  5.87355301e+00 5.95718306e+00 7.05961970e+00 9.45211267e+00
#  9.77772289e+00 9.77522274e+00 9.62586561e+00 6.67286606e+00
#  6.33946981e+00 6.91801522e+00 5.44576779e+00 8.07962219e+00
#  8.89332662e+00 8.98830700e+00 7.53275034e+00 7.67827875e+00
#  9.11449223e+00 1.08751188e+01 1.13544851e+01 1.33355745e+01
#  1.42849823e+01 1.33799270e+01 1.39295208e+01 1.35835898e+01
#  1.37285498e+01 1.42272448e+01 1.51843505e+01 1.48576165e+01
#  1.52645013e+01 1.64171803e+01 1.30569892e+01 1.47386353e+01
#  1.48091914e+01 1.63110788e+01 1.63993805e+01 1.52916117e+01
#  1.69372484e+01 1.50992128e+01 1.60430340e+01 1.79806311e+01
#  2.03781774e+01 2.18060302e+01 2.17715419e+01 2.14735586e+01
# ...

# %%
T = 200
true = [10 for i in range(T)]
leaf_list40 = []
for i in range(40):
    leaf_list = (np.random.laplace(0, (1/1), T)) + true
    leaf_list_ = [i if i >=0 else 0 for i in leaf_list]

    cdf_leaf_noise = np.array([sum(leaf_list_[ : i + 1]) for i in range(len(leaf_list_))])
    cdf_leaf_true = np.array([sum(true[ : i + 1]) for i in range(len(true))])
    leaf_error = np.abs(cdf_leaf_noise - cdf_leaf_true)
    leaf_list40.append(leaf_error)

leaf = np.sum(leaf_list40, axis = 0)

bins = 40
for i in range(T):
    true_hist = [25 for i in range(bins)]
    noisy_hist = true_hist + (np.random.laplace(0, (1/1), bins))
    


leaf = np.abs(cdf_leaf_noise - cdf_leaf_true)
baseline_list = (np.random.laplace(0, (T/1), T))
baseline = np.abs(baseline_list)
#sortD = [5, 5, 12, 13, 12, 11, 19, 25, 12, 13, 19, 22, 22, 21, 27, 38, 14, 13, 20, 23, 20, 22, 27, 35, 20, 20, 27, 30, 29, 27, 36, 59, 12, 13, 19, 25, 22, 24, 28, 36, 20, 24, 28, 31, 31, 29, 38, 52, 21, 21, 29, 32, 30, 30, 37, 46, 29, 28, 40, 39, 38, 38, 48, 78, 14, 12, 20, 23, 18, 22, 28, 34, 19, 24, 28, 30, 29, 31, 38, 49, 21, 22, 30, 33, 28, 30, 38, 46, 30, 30, 38, 44, 38, 37, 51, 65, 21, 22, 29, 32]
x1 = np.linspace(1, T, T)

#plt.scatter(x1, sortD)
plt.scatter(x1, leaf)
#plt.scatter(x1, baseline)

plt.show()
print(test_list)
print(leaf)
# Out:
# [1, 2, 3, 4]
# [ 0.03334091  3.9220714   3.74113856  0.4509722   0.13988403  0.60223153
#   1.5393729   0.03774395  0.98957038  1.41680695  1.27133672  0.26081724
#   0.28206375  0.51832265  0.46238177  0.68715218  0.41673653  4.07168091
#   2.17246052  1.93130716  3.4720949   4.75611624  5.03646308  4.82550236
#   6.67924175  5.96262858  4.28722867  4.04579207  4.18038525  4.16962596
#   4.43556261  3.66726154  3.37221069  1.7604945   0.86967571  0.67437327
#   1.55615578  1.95720067  1.90557412  2.40843604  2.32980894  0.21709725
#   0.11243396  0.64674439  0.36058668  2.89378594  2.72524222  2.29186836
#   3.4701143   2.71166021  2.49942607  6.8025702   8.09274206  8.23199911
#   8.32138873  8.35389851  8.60845452  9.34305231 10.99297571 10.47373929
#   9.98975112  9.41285518 10.86452196 11.11323112  8.74669489  8.8385581
#   3.79015087  3.06312667  3.17434398  2.57475765  1.68228914  0.37846249
#   2.3306811   4.84652813  2.84395057  2.84922118  3.32916497  5.56841927
# ...

# %%
test_list = [1,2,3,4]
leaf = [sum(test_list[ : i + 1]) for i in range(len(test_list))]

# %%
leaf
# Out:
# [1, 3, 6, 10]

# %%
import math
T = 1000
x1 = np.linspace(1, T, T)
log2 = [math.log2(i+1) for i in range(T)]
plt.scatter(x1, log2)

plt.show()

# %%
np.sum(np.array([[1,2],[3,4]]), axis=0)
# Out:
# array([4, 6])

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
baseline_list = (np.random.laplace(0, (200/1), 100))

np.mean(np.abs(baseline_list))
# Out:
# 191.8057396341863
