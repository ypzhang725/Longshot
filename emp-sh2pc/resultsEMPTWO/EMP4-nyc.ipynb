# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import re
import json
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
def string2vect(string, name):
   # print(string)
   # print(name)
    string_result = re.search(name + ': (.*)\n', string).group(1)
    vect = [float(e) for e in string_result.split(",")]

    return vect

# %%
def readFileReturnMeanAll(fileName):
    with open(fileName) as f:
        lines = f.readlines()
    numPrint = 12
    runs = int(len(lines) / numPrint)
    '''
    print(runs)
    for i in range(12):
        print(lines[i])
    ''' 
    metricRunTimeDP = [None]*runs
    metricRunTimeDPSort = [None]*runs
    metricRunTimeDPMerge = [None]*runs
    metricRunTimePointQuery = [None]*runs
    metricRunTimeRangeQuery = [None]*runs
    metricDPErrorP = [None]*runs
    metricDPStoreErrorP = [None]*runs
    metricTTStoreErrorP = [None]*runs
    metricDPErrorR = [None]*runs
    metricDPStoreErrorR = [None]*runs
    metricTTStoreErrorR = [None]*runs
    
    metricRunTimeDPSort = [None]*runs
    metricDPError = [None]*runs
    metricDPStoreError = [None]*runs
    for i in range(runs):
        metricRunTimeDP[i] = string2vect(lines[(i*numPrint) + 1], 'metricRunTimeDP')
        metricRunTimeDPSort[i] = string2vect(lines[(i*numPrint) + 2], 'metricRunTimeDPSort')
        metricRunTimeDPMerge[i] = string2vect(lines[(i*numPrint) + 3], 'metricRunTimeDPMerge')
        metricRunTimePointQuery[i] = string2vect(lines[(i*numPrint) + 4], 'metricRunTimePointQuery')
        metricRunTimeRangeQuery[i] = string2vect(lines[(i*numPrint) + 5], 'metricRunTimeRangeQuery')
        metricDPErrorP[i] = string2vect(lines[(i*numPrint) +6], 'metricDPErrorP')
        metricDPStoreErrorP[i] = string2vect(lines[(i*numPrint) + 7], 'metricDPStoreErrorP')
        metricTTStoreErrorP[i] = string2vect(lines[(i*numPrint) + 8], 'metricTTStoreErrorP')
        metricDPErrorR[i] = string2vect(lines[(i*numPrint) + 9], 'metricDPErrorR')
        metricDPStoreErrorR[i] = string2vect(lines[(i*numPrint) + 10], 'metricDPStoreErrorR')
        metricTTStoreErrorR[i] = string2vect(lines[(i*numPrint) + 11], 'metricTTStoreErrorR')
       

    metricRunTimeDP_mean = np.mean(np.array(metricRunTimeDP), axis = 0)
    metricRunTimeDPSort_mean = np.mean(np.array(metricRunTimeDPSort), axis = 0)
    metricRunTimeDPMerge_mean = np.mean(np.array(metricRunTimeDPMerge), axis = 0)
    metricRunTimePointQuery_mean = np.mean(np.array(metricRunTimePointQuery), axis = 0)
    metricRunTimeRangeQuery_mean = np.mean(np.array(metricRunTimeRangeQuery), axis = 0)
    metricDPErrorP_mean = np.mean(np.array(metricDPErrorP), axis = 0)
    metricDPStoreErrorP_mean = np.mean(np.array(metricDPStoreErrorP), axis = 0)
    metricTTStoreErrorP_mean = np.mean(np.array(metricTTStoreErrorP), axis = 0)
    metricDPErrorR_mean = np.mean(np.array(metricDPErrorR), axis = 0)
    metricDPStoreErrorR_mean = np.mean(np.array(metricDPStoreErrorR), axis = 0)
    metricTTStoreErrorR_mean = np.mean(np.array(metricTTStoreErrorR), axis = 0)
    
    d = dict(); 
    d['metricRunTimeDP_mean'] = metricRunTimeDP_mean
    d['metricRunTimeDPSort_mean'] = metricRunTimeDPSort_mean
    d['metricRunTimeDPMerge_mean'] = metricRunTimeDPMerge_mean
    d['metricRunTimePointQuery_mean'] = metricRunTimePointQuery_mean
    d['metricRunTimeRangeQuery_mean'] = metricRunTimeRangeQuery_mean
    d['metricDPErrorP_mean'] = metricDPErrorP_mean
    d['metricDPStoreErrorP_mean'] = metricDPStoreErrorP_mean
    d['metricTTStoreErrorP_mean'] = metricTTStoreErrorP_mean
    d['metricDPErrorR_mean'] = metricDPErrorR_mean
    d['metricDPStoreErrorR_mean'] = metricDPStoreErrorR_mean
    d['metricTTStoreErrorR_mean'] = metricTTStoreErrorR_mean
    '''
    print(metricRunTimeDP)
    print(metricRunTimeDPSort)
    print(metricRunTimeDPMerge)
    print(metricRunTimePointQuery)
    print(metricRunTimeRangeQuery)
    print(metricDPErrorP)
    print(metricDPStoreErrorP)
    print(metricTTStoreErrorP)
    print(metricDPErrorR)
    print(metricDPStoreErrorR)
    print(metricTTStoreErrorR)
    '''
    return d

# %%
def readFileReturnMeanTree(fileName):
    with open(fileName) as f:
        lines = f.readlines()
    numPrint = 11
    runs = int(len(lines) / numPrint)
    '''
    print(runs)
    for i in range(12):
        print(lines[i])
    '''  
    metricRunTimeDP = [None]*runs
    metricRunTimeDPSort = [None]*runs
 #   metricRunTimeDPMerge = [None]*runs
    metricRunTimePointQuery = [None]*runs
    metricRunTimeRangeQuery = [None]*runs
    metricDPErrorP = [None]*runs
    metricDPStoreErrorP = [None]*runs
    metricTTStoreErrorP = [None]*runs
    metricDPErrorR = [None]*runs
    metricDPStoreErrorR = [None]*runs
    metricTTStoreErrorR = [None]*runs
    
    metricRunTimeDPSort = [None]*runs
    metricDPError = [None]*runs
    metricDPStoreError = [None]*runs
    for i in range(runs):
        metricRunTimeDP[i] = string2vect(lines[(i*numPrint) + 1], 'metricRunTimeDP')
        metricRunTimeDPSort[i] = string2vect(lines[(i*numPrint) + 2], 'metricRunTimeDPSort')
     #   metricRunTimeDPMerge[i] = string2vect(lines[(i*numPrint) + 3], 'metricRunTimeDPMerge')
        metricRunTimePointQuery[i] = string2vect(lines[(i*numPrint) + 3], 'metricRunTimePointQuery')
        metricRunTimeRangeQuery[i] = string2vect(lines[(i*numPrint) + 4], 'metricRunTimeRangeQuery')
        metricDPErrorP[i] = string2vect(lines[(i*numPrint) +5], 'metricDPErrorP')
        metricDPStoreErrorP[i] = string2vect(lines[(i*numPrint) + 6], 'metricDPStoreErrorP')
        metricTTStoreErrorP[i] = string2vect(lines[(i*numPrint) + 7], 'metricTTStoreErrorP')
        metricDPErrorR[i] = string2vect(lines[(i*numPrint) + 8], 'metricDPErrorR')
        metricDPStoreErrorR[i] = string2vect(lines[(i*numPrint) + 9], 'metricDPStoreErrorR')
        metricTTStoreErrorR[i] = string2vect(lines[(i*numPrint) + 10], 'metricTTStoreErrorR')
       

    metricRunTimeDP_mean = np.mean(np.array(metricRunTimeDP), axis = 0)
    metricRunTimeDPSort_mean = np.mean(np.array(metricRunTimeDPSort), axis = 0)
  #  metricRunTimeDPMerge_mean = np.mean(np.array(metricRunTimeDPMerge), axis = 0)
    metricRunTimePointQuery_mean = np.mean(np.array(metricRunTimePointQuery), axis = 0)
    metricRunTimeRangeQuery_mean = np.mean(np.array(metricRunTimeRangeQuery), axis = 0)
    metricDPErrorP_mean = np.mean(np.array(metricDPErrorP), axis = 0)
    metricDPStoreErrorP_mean = np.mean(np.array(metricDPStoreErrorP), axis = 0)
    metricTTStoreErrorP_mean = np.mean(np.array(metricTTStoreErrorP), axis = 0)
    metricDPErrorR_mean = np.mean(np.array(metricDPErrorR), axis = 0)
    metricDPStoreErrorR_mean = np.mean(np.array(metricDPStoreErrorR), axis = 0)
    metricTTStoreErrorR_mean = np.mean(np.array(metricTTStoreErrorR), axis = 0)
    
    d = dict(); 
    d['metricRunTimeDP_mean'] = metricRunTimeDP_mean
    d['metricRunTimeDPSort_mean'] = metricRunTimeDPSort_mean
 #   d['metricRunTimeDPMerge_mean'] = metricRunTimeDPMerge_mean
    d['metricRunTimePointQuery_mean'] = metricRunTimePointQuery_mean
    d['metricRunTimeRangeQuery_mean'] = metricRunTimeRangeQuery_mean
    d['metricDPErrorP_mean'] = metricDPErrorP_mean
    d['metricDPStoreErrorP_mean'] = metricDPStoreErrorP_mean
    d['metricTTStoreErrorP_mean'] = metricTTStoreErrorP_mean
    d['metricDPErrorR_mean'] = metricDPErrorR_mean
    d['metricDPStoreErrorR_mean'] = metricDPStoreErrorR_mean
    d['metricTTStoreErrorR_mean'] = metricTTStoreErrorR_mean
    '''
    print(metricRunTimeDP)
    print(metricRunTimeDPSort)
    print(metricRunTimeDPMerge)
    print(metricRunTimePointQuery)
    print(metricRunTimeRangeQuery)
    print(metricDPErrorP)
    print(metricDPStoreErrorP)
    print(metricTTStoreErrorP)
    print(metricDPErrorR)
    print(metricDPStoreErrorR)
    print(metricTTStoreErrorR)
    '''
    return d

# %%
def readFileReturnMeanBaseline(fileName):
    with open(fileName) as f:
        lines = f.readlines()
    numPrint = 9
    runs = int(len(lines) / numPrint)
    '''
    print(runs)
    for i in range(9):
        print(lines[i])
    '''    
    metricRunTimePoint = [None]*runs
    metricDPErrorPoint = [None]*runs
    metricDPStoreErrorPoint = [None]*runs
    metricTTStoreErrorPoint = [None]*runs
    metricRunTimeRange = [None]*runs
    metricDPErrorRange = [None]*runs
    metricDPStoreErrorRange = [None]*runs
    metricTTStoreErrorRange = [None]*runs

    for i in range(runs):
        metricRunTimePoint[i] = string2vect(lines[(i*numPrint) + 1], 'metricRunTimePoint')
        metricDPErrorPoint[i] = string2vect(lines[(i*numPrint) + 2], 'metricDPErrorPoint')
        metricDPStoreErrorPoint[i] = string2vect(lines[(i*numPrint) + 3], 'metricDPStoreErrorPoint')
        metricTTStoreErrorPoint[i] = string2vect(lines[(i*numPrint) + 4], 'metricTTStoreErrorPoint')
        metricRunTimeRange[i] = string2vect(lines[(i*numPrint) + 5], 'metricRunTimeRange')
        metricDPErrorRange[i] = string2vect(lines[(i*numPrint) +6], 'metricDPErrorRange')
        metricDPStoreErrorRange[i] = string2vect(lines[(i*numPrint) + 7], 'metricDPStoreErrorRange')
        metricTTStoreErrorRange[i] = string2vect(lines[(i*numPrint) + 8], 'metricTTStoreErrorRange')
       

    metricRunTimePoint_mean = np.mean(np.array(metricRunTimePoint), axis = 0)
    metricDPErrorPoint_mean = np.mean(np.array(metricDPErrorPoint), axis = 0)
    metricDPStoreErrorPoint_mean = np.mean(np.array(metricDPStoreErrorPoint), axis = 0)
    metricTTStoreErrorPoint_mean = np.mean(np.array(metricTTStoreErrorPoint), axis = 0)
    metricRunTimeRange_mean = np.mean(np.array(metricRunTimeRange), axis = 0)
    metricDPErrorRange_mean = np.mean(np.array(metricDPErrorRange), axis = 0)
    metricDPStoreErrorRange_mean = np.mean(np.array(metricDPStoreErrorRange), axis = 0)
    metricTTStoreErrorRange_mean = np.mean(np.array(metricTTStoreErrorRange), axis = 0)
     
    d = dict(); 
    d['metricRunTimePoint_mean'] = metricRunTimePoint_mean
    d['metricDPErrorPoint_mean'] = metricDPErrorPoint_mean
    d['metricDPStoreErrorPoint_mean'] = metricDPStoreErrorPoint_mean
    d['metricTTStoreErrorPoint_mean'] = metricTTStoreErrorPoint_mean
    d['metricRunTimeRange_mean'] = metricRunTimeRange_mean
    d['metricDPErrorRange_mean'] = metricDPErrorRange_mean
    d['metricDPStoreErrorRange_mean'] = metricDPStoreErrorRange_mean
    d['metricTTStoreErrorRange_mean'] = metricTTStoreErrorRange_mean
    
    '''
    print(metricRunTimePoint)
    print(metricDPErrorPoint)
    print(metricDPStoreErrorPoint)
    print(metricTTStoreErrorPoint)
    print(metricRunTimeRange)
    print(metricDPErrorRange)
    print(metricDPStoreErrorRange)
    print(metricTTStoreErrorRange)
    '''
    
    return d

# %%
np.linspace(1, 4, 4, endpoint=True)
# Out:
# array([1., 2., 3., 4.])

# %%
def plotQuery(T, arrayLeaf, arrayTree_baseline, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, 10, 10, endpoint=True)
    y1points = arrayLeaf
    y2points = arrayTree_baseline
    y3points = arrayTree_sortD
    
    #plt.subplot(1, 1, 1)
    plt.plot(xpoints, y1points, 'b.', label="Leaf")
    plt.plot(x1points, y2points, 'r.', label="Baseline")
    plt.plot(xpoints, y3points, 'g.', label="Tree-OPT")

    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
    plt.legend(loc="upper right", prop={'size': 16})
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
    plt.yscale('log', base=10) 
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q1-1-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()

# %%
def plotQ11(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "0.001leafbin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameBaseline = "baselinebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanBaseline = readFileReturnMeanBaseline(fileNameBaseline)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)

    # three metrics
    #leaf 
    LeafRunTimePoint_mean = returnedMeanLeaf["metricRunTimePointQuery_mean"]
    LeafRunTimeRange_mean = returnedMeanLeaf["metricRunTimeRangeQuery_mean"]
    #baseline
    BaselineRunTimePoint_mean = returnedMeanBaseline["metricRunTimePoint_mean"]
    BaselineRunTimeRange_mean = returnedMeanBaseline["metricRunTimeRange_mean"]
    #tree_sortD
    SortDRunTimePoint_mean = returnedMeanSortD["metricRunTimePointQuery_mean"]
    SortDRunTimeRange_mean = returnedMeanSortD["metricRunTimeRangeQuery_mean"]
 #   print(LeafRunTimePoint_mean)
 #   print(LeafRunTimeRange_mean)
 #   print(BaselineRunTimePoint_mean)
 #   print(BaselineRunTimeRange_mean)
 #   print(SortDRunTimePoint_mean)
 #   print(SortDRunTimeRange_mean)
    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    plotQuery(T, LeafRunTimePoint_mean, BaselineRunTimePoint_mean, SortDRunTimePoint_mean, "The number of updates", "Runtime-PointQuery(ms)", title)
    plotQuery(T, LeafRunTimeRange_mean, BaselineRunTimeRange_mean, SortDRunTimeRange_mean, "The number of updates", "Runtime-RangeQuery(ms)", title)

# %%
# Q1-runtime: EMP
# x axis: T
# y axis: query processing time for baseline and DP structure appoaches
T = 200
eps = 1
N = 1000  # bigger N 1000, 10000
plotQ11(T, eps, N)
#todo: average time/query; label, fix x axis 
# baseline: 10 T
# DP structure larger T constant 1000

# %%
def plotDPSeperate(T, arrayLeaf, arrayTree_sortSubroot, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, 10, 10, endpoint=True)
    y1points = arrayLeaf
    y2points = arrayTree_sortSubroot
    y3points = arrayTree_sortD

    #plt.subplot(1, 1, 1)
    plt.plot(xpoints, y1points, 'b.', label="Leaf")
    plt.plot(xpoints, y3points, 'g.', label="Tree-OPT")
    plt.plot(x1points, y2points, 'r.', label="Baseline")

    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
    plt.legend(loc="upper right", prop={'size': 16})
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
   # plt.yscale('log',base=10) 
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q1-2-"+ylable+"-"+title+".pdf", bbox_inches='tight')

    plt.show()


    
def plotQ12(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "0.001leafbin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameBaseline = "baselinebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanBaseline = readFileReturnMeanBaseline(fileNameBaseline)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
    
    # six metrics 
    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    # point query
    # leaf 
    LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
    LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
    LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
    # baseline
    BaselineDPError_mean = returnedMeanBaseline["metricDPErrorPoint_mean"]
    BaselineDPStoreError_mean = returnedMeanBaseline["metricDPStoreErrorPoint_mean"]
    BaselineTTStoreError_mean = returnedMeanBaseline["metricTTStoreErrorPoint_mean"]
    # tree_sortD
    SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
    SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
    SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]

    
    plotDPSeperate(T, LeafDPError_mean, BaselineDPError_mean, SortDDPError_mean, "The number of updates", "DPCountError-PointQuery", title)
    plotDPSeperate(T, LeafTTStoreError_mean, BaselineTTStoreError_mean, SortDTTStoreError_mean, "The number of updates", "TrueRecordError-PointQuery", title)
    plotDPSeperate(T, LeafDPStoreError_mean, BaselineDPStoreError_mean, SortDDPStoreError_mean, "The number of updates", "DPStoreError-PointQuery", title)
 
    # range query
    # leaf 
    LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
    LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
    LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
    # baseline
    BaselineDPErrorRange_mean = returnedMeanBaseline["metricDPErrorRange_mean"]
    BaselineDPStoreErrorRange_mean = returnedMeanBaseline["metricDPStoreErrorRange_mean"]
    BaselineTTStoreErrorRange_mean = returnedMeanBaseline["metricTTStoreErrorRange_mean"]
    # tree_sortD
    SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
    SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
    SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]

    
    plotDPSeperate(T, LeafDPErrorRange_mean, BaselineDPErrorRange_mean, SortDDPErrorRange_mean, "The number of updates", "DPCountError-RangeQuery", title)
    plotDPSeperate(T, LeafTTStoreErrorRange_mean, BaselineTTStoreErrorRange_mean, SortDTTStoreErrorRange_mean, "The number of updates", "TrueRecordError-RangeQuery", title)
    plotDPSeperate(T, LeafDPStoreErrorRange_mean, BaselineDPStoreErrorRange_mean, SortDDPStoreErrorRange_mean, "The number of updates", "DPStoreError-RangeQuery", title)

   # plotDPSeperate(T, LeafDPErrorRange_mean, [0 for i in range(10)], SortDDPErrorRange_mean, "The number of updates", "DPCountError for range query", title)
   # plotDPSeperate(T, LeafTTStoreErrorRange_mean, [0 for i in range(10)], SortDTTStoreErrorRange_mean, "The number of updates", "TrueRecordError for range query", title)
   # plotDPSeperate(T, LeafDPStoreErrorRange_mean, [0 for i in range(10)], SortDDPStoreErrorRange_mean, "The number of updates", "DPStoreError for range query", title)

# %%
# Q1-accuracy: emp
# x axis: T
# y axis: three errors for point and range queries 
T = 200
eps = 1
N = 1000
plotQ12(T, eps, N)
# T 1000

# %%
def plotDPSeperate13(T, arrayLeaf, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, 200, 200, endpoint=True)
    y1points = arrayLeaf
    y3points = arrayTree_sortD
    
    begin = y1points[0]
    end = y1points[-1]
    slope = (end - begin) / 200
    leaf = [(i-1)*slope+begin for i in xpoints]
    #plt.subplot(1, 1, 1)
    plt.plot(xpoints, leaf, 'c.', label="Leaf-extrapolated")
    plt.plot(x1points, y1points, 'b.', label="Leaf")
    plt.plot(xpoints, y3points, 'g.', label="Tree-OPT")

    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
    plt.legend(loc="upper left", prop={'size': 16})
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
   # plt.yscale('log',base=10) 
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q1-3-LeafTree-"+ylable+"-"+title+".pdf", bbox_inches='tight')

    plt.show()


    
def plotQ13(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "0.001leafbin40_total_amount_ss1.txt,"+"200,"+eps_string+N_string+";2.txt"
    fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
    
    # six metrics 
    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    # point query
    # leaf 
    LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
    LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
    LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]

    # tree_sortD
    SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
    SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
    SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]

    
    plotDPSeperate13(T, LeafDPError_mean, SortDDPError_mean, "The number of updates", "DPCountError-PointQuery", title)
    plotDPSeperate13(T, LeafTTStoreError_mean, SortDTTStoreError_mean, "The number of updates", "TrueRecordError-PointQuery", title)
    plotDPSeperate13(T, LeafDPStoreError_mean, SortDDPStoreError_mean, "The number of updates", "DPStoreError-PointQuery", title)
 
    # range query
    # leaf 
    LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
    LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
    LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
  
    # tree_sortD
    SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
    SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
    SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]

    
    plotDPSeperate13(T, LeafDPErrorRange_mean, SortDDPErrorRange_mean, "The number of updates", "DPCountError-RangeQuery", title)
    plotDPSeperate13(T, LeafTTStoreErrorRange_mean, SortDTTStoreErrorRange_mean, "The number of updates", "TrueRecordError-RangeQuery", title)
    plotDPSeperate13(T, LeafDPStoreErrorRange_mean, SortDDPStoreErrorRange_mean, "The number of updates", "DPStoreError-RangeQuery", title)

   # plotDPSeperate13(T, LeafDPErrorRange_mean, [0 for i in range(10)], SortDDPErrorRange_mean, "The number of updates", "DPCountError for range query", title)
   # plotDPSeperate13(T, LeafTTStoreErrorRange_mean, [0 for i in range(10)], SortDTTStoreErrorRange_mean, "The number of updates", "TrueRecordError for range query", title)
   # plotDPSeperate13(T, LeafDPStoreErrorRange_mean, [0 for i in range(10)], SortDDPStoreErrorRange_mean, "The number of updates", "DPStoreError for range query", title)

# %%
# Q1-accuracy: emp
# x axis: T
# y axis: three errors for point and range queries 
T = 600
eps = 1
N = 1000
plotQ13(T, eps, N)
# T 1000

# %%
def plotCache(T, arrayLeaf, arrayTree_sortSubroot, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    y1points = arrayLeaf
    y2points = arrayTree_sortSubroot
    y3points = arrayTree_sortD
    
    #plt.subplot(1, 1, 1)
    plt.plot(xpoints, y1points, 'b^', label="CacheDummy_leaf")
    plt.plot(xpoints, y2points, 'r^', label="CacheDummy_tree_sortSubRoot")
    plt.plot(xpoints, y3points, 'go', label="CacheDummy_tree_sortD")

    plt.xlabel(xlable)
    plt.ylabel(ylable)
    plt.legend(loc="upper left", prop={'size': 8})

    plt.title(title)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q2-"+ylable+"-"+title+".pdf", bbox_inches='tight')

    plt.show()


def plotSort(T, arrayLeaf, arrayTree_sortA, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, T, T, endpoint=True)
    y1points = arrayLeaf
    y2points = arrayTree_sortA
    y3points = arrayTree_sortD
    
    #plt.subplot(1, 1, 1)
    plt.plot(xpoints, y1points, 'b.', label="Leaf")
    plt.plot(x1points, y2points, 'r.', label="Tree-ALL")
    plt.plot(xpoints, y3points, 'g.', label="Tree-OPT")

    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
    plt.legend(loc="upper left", prop={'size': 14})
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q2-1-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()
    
def plotQ21(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "0.001leafbin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameTreeSortA = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",0;0.txt"
    fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanTreeSortA = readFileReturnMeanTree(fileNameTreeSortA)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)           
            
            
    # six metrics
        #leaf 
    LeafRunTimeDPSort_mean = returnedMeanLeaf["metricRunTimeDPSort_mean"]
  #  LeafCacheNum_mean = data_loaded["list_dummyRecordNumCache_leaf"]
        #tree_sortRoot
    SortRootRunTimeDPSort_mean = returnedMeanTreeSortA["metricRunTimeDPSort_mean"]
  #  SortRootCacheNum_mean = data_loaded["list_dummyRecordNumCache_treeA"]
        #tree_sortD
    SortDRunTimeDPSort_mean = returnedMeanSortD["metricRunTimeDPSort_mean"]
  #  SortDCacheNum_mean = data_loaded["list_dummyRecordNumCache_treeD"]

    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    plotSort(T, LeafRunTimeDPSort_mean, SortRootRunTimeDPSort_mean, SortDRunTimeDPSort_mean, "The number of updates", "Runtime(s)", title)
  #  plotCache(T, LeafCacheNum_mean, SortRootCacheNum_mean, SortDCacheNum_mean, "time", "numOfDummy", title)


def plotDPSeperate2(T, arrayTree_sortSubroot, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, T, T, endpoint=True)
   # y1points = arrayLeaf
    y2points = arrayTree_sortSubroot
    y3points = arrayTree_sortD

    #plt.subplot(1, 1, 1)
  #  plt.plot(xpoints, y1points, 'b^', label="Leaf")
    plt.plot(x1points, y2points, 'r.', label="Tree-ALL")
    plt.plot(xpoints, y3points, 'g.', label="Tree-OPT")

    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
    plt.legend(loc="upper left", prop={'size': 16})
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q2-2-"+ylable+"-"+title+".pdf", bbox_inches='tight')

    plt.show()


    
def plotQ22new(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "0.001leafbin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameTreeSortA = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",0;0.txt"
    fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanSortA = readFileReturnMeanTree(fileNameTreeSortA)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
    
    # six metrics 
    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    # point query
    # leaf 
    LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
    LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
    LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
    # tree_sortA
    SortADPError_mean = returnedMeanSortA["metricDPErrorP_mean"]
    SortADPStoreError_mean = returnedMeanSortA["metricDPStoreErrorP_mean"]
    SortATTStoreError_mean = returnedMeanSortA["metricTTStoreErrorP_mean"]
    # tree_sortD
    SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
    SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
    SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]

    
    plotDPSeperate2(T, SortADPError_mean, SortDDPError_mean, "The number of updates", "DPCountError-PointQuery", title)
    plotDPSeperate2(T, SortATTStoreError_mean, SortDTTStoreError_mean, "The number of updates", "TrueRecordError-PointQuery", title)
    plotDPSeperate2(T, SortADPStoreError_mean, SortDDPStoreError_mean, "The number of updates", "DPStoreError-PointQuery", title)
 
    # range query
    # leaf 
    LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
    LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
    LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
    # tree_sortA
    SortADPErrorRange_mean = returnedMeanSortA["metricDPErrorR_mean"]
    SortADPStoreErrorRange_mean = returnedMeanSortA["metricDPStoreErrorR_mean"]
    SortATTStoreErrorRange_mean = returnedMeanSortA["metricTTStoreErrorR_mean"]
    # tree_sortD
    SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
    SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
    SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]

    
    plotDPSeperate2(T, SortADPErrorRange_mean, SortDDPErrorRange_mean, "The number of updates", "DPCountError-RangeQuery", title)
    plotDPSeperate2(T, SortATTStoreErrorRange_mean, SortDTTStoreErrorRange_mean, "The number of updates", "TrueRecordError-RangeQuery", title)
    plotDPSeperate2(T, SortADPStoreErrorRange_mean, SortDDPStoreErrorRange_mean, "The number of updates", "DPStoreError-RangeQuery", title)

# %%
# Q2-DPStore-sortTime: emp
# x axis: T
# y axis: sortTime  
T = 200
eps = 1
N = 1000
plotQ21(T, eps, N)
plotQ22new(T, eps, N)

# %%
np.mean([[1, 2, 3], [4, 5, 6], [7, 8, 9]], axis = 1)
# Out:
# array([2., 5., 8.])

# %%
def plotDP1Approach(T, DPError, DPStore, TTStore, xlable, ylable, title):
    DPError_mean = np.mean(DPError, axis = 1)
    DPStore_mean = np.mean(DPStore, axis = 1)
    TTStore_mean = np.mean(TTStore, axis = 1)
    
    #plt.subplot(1, 1, 1)
 #   y_pos = np.linspace(1, 4, 4, endpoint=True)
    
   # y_points = [y1points, y2points, y3points, y4points]
   # plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
    
   # plt.bar(y_pos +0.20, DPError_mean, width=0.2, label = 'DPCountError')
   # plt.bar(y_pos +0.20*2, DPStore_mean, width=0.2, label = 'DPStoreError')
   # plt.bar(y_pos +0.20*3, TTStore_mean, width=0.2, label = 'TrueRecordError')
    x = [0.25,0.5,1,2]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, DPError_mean, label = 'DPCountError', marker = 'o')
    plt.plot(default_x_ticks, DPStore_mean, label = 'DPStoreError', marker = 'o')
    plt.plot(default_x_ticks, TTStore_mean, label = 'TrueRecordError', marker = 'o')
    plt.xticks(default_x_ticks, x)

    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
    plt.legend(loc="upper left", prop={'size': 16})
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q31-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()

    
def plotSort3(T, eps1, eps2, eps3, eps4, xlable, ylable, title):
    y1points = np.mean(eps1)
    y2points = np.mean(eps2)
    y3points = np.mean(eps3)
    y4points = np.mean(eps4)
    
    #plt.subplot(1, 1, 1)
 #   y_pos = np.linspace(1, 4, 4, endpoint=True)
  #  plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
  #  plt.xticks(y_pos, objects)
    x = [0.25,0.5,1,2]
    y_points = [y1points, y2points, y3points, y4points]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, y_points, marker = 'o')
    plt.xticks(default_x_ticks, x)
    
    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
   # plt.legend(loc="upper right", prop={'size': 14})
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q31-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()
    
def plotQ31(T, epsList, N):
    # create file names
    T_string = str(T)+","
    N_string = str(N)
    LeafDPError_mean_list = []
    LeafDPStoreError_mean_list = []
    LeafTTStoreError_mean_list = []
    LeafDPErrorRange_mean_list = []
    LeafDPStoreErrorRange_mean_list = []
    LeafTTStoreErrorRange_mean_list = []
    
    SortDDPError_mean_list = []
    SortDDPStoreError_mean_list = []
    SortDTTStoreError_mean_list = []
    SortDDPErrorRange_mean_list = []
    SortDDPStoreErrorRange_mean_list = []
    SortDTTStoreErrorRange_mean_list = []
    
    LeafDRunTimeDPSort_mean_list = []
    SortDRunTimeDPSort_mean_list = []
    
    for eps in epsList:
        eps_string = str(eps)+","
    #    fileNameLeaf = "leafbin40_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
        fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
        # read files, parse and return mean
 #       returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
        returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
        # point query
        # leaf 
  #      LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
  #      LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
  #      LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
        
  #      LeafDPError_mean_list.append(LeafDPError_mean)
  #      LeafDPStoreError_mean_list.append(LeafDPStoreError_mean)
  #      LeafTTStoreError_mean_list.append(LeafTTStoreError_mean)
        
        # tree_sortD
        SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
        SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
        SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]
        
        SortDDPError_mean_list.append(SortDDPError_mean)
        SortDDPStoreError_mean_list.append(SortDDPStoreError_mean)
        SortDTTStoreError_mean_list.append(SortDTTStoreError_mean)
        
        
        # range query
        # leaf 
  #      LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
  #      LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
  #      LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
        
  #      LeafDPErrorRange_mean_list.append(LeafDPErrorRange_mean)
  #      LeafDPStoreErrorRange_mean_list.append(LeafDPStoreErrorRange_mean)
  #      LeafTTStoreErrorRange_mean_list.append(LeafTTStoreErrorRange_mean)
        
        # tree_sortD
        SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
        SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
        SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]
        
        SortDDPErrorRange_mean_list.append(SortDDPErrorRange_mean)
        SortDDPStoreErrorRange_mean_list.append(SortDDPStoreErrorRange_mean)
        SortDTTStoreErrorRange_mean_list.append(SortDTTStoreErrorRange_mean)
        
        
  #      LeafDRunTimeDPSort_mean = returnedMeanLeaf["metricRunTimeDPSort_mean"]
        SortDRunTimeDPSort_mean = returnedMeanSortD["metricRunTimeDPSort_mean"]
  #      LeafDRunTimeDPSort_mean_list.append(LeafDRunTimeDPSort_mean)
        SortDRunTimeDPSort_mean_list.append(SortDRunTimeDPSort_mean)

        
    # six metrics 
   # title = "T:"+str(T)+"; eps:"+str(eps)+"; N:"+str(N)
    
    title = "Q3"
    
 #   plotDP1Approach(T, LeafDPError_mean_list[0], LeafDPError_mean_list[1], LeafDPError_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafDPStoreError_mean_list[0], LeafDPStoreError_mean_list[1], LeafDPStoreError_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafTTStoreError_mean_list[0], LeafTTStoreError_mean_list[1], LeafTTStoreError_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Point query")
 
 #   plotDP1Approach(T, LeafDPErrorRange_mean_list[0], LeafDPErrorRange_mean_list[1], LeafDPErrorRange_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafDPStoreErrorRange_mean_list[0], LeafDPStoreErrorRange_mean_list[1], LeafDPStoreErrorRange_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafTTStoreErrorRange_mean_list[0], LeafTTStoreErrorRange_mean_list[1], LeafTTStoreErrorRange_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Range query")

    plotDP1Approach(T, SortDDPError_mean_list, SortDDPStoreError_mean_list, SortDTTStoreError_mean_list, "Privacy parameter $\epsilon$", "Errors", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDDPStoreError_mean_list[0], SortDDPStoreError_mean_list[1], SortDDPStoreError_mean_list[2], SortDDPStoreError_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDTTStoreError_mean_list[0], SortDTTStoreError_mean_list[1], SortDTTStoreError_mean_list[2], SortDTTStoreError_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Point query")
 
    plotDP1Approach(T, SortDDPErrorRange_mean_list, SortDDPStoreErrorRange_mean_list, SortDTTStoreErrorRange_mean_list, "Privacy parameter $\epsilon$", "Errors", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDDPStoreErrorRange_mean_list[0], SortDDPStoreErrorRange_mean_list[1], SortDDPStoreErrorRange_mean_list[2], SortDDPStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDTTStoreErrorRange_mean_list[0], SortDTTStoreErrorRange_mean_list[1], SortDTTStoreErrorRange_mean_list[2], SortDTTStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Range query")


#    plotSort3(T, LeafDRunTimeDPSort_mean_list[0], LeafDRunTimeDPSort_mean_list[1], LeafDRunTimeDPSort_mean_list[2], "The number of updates", "Runtime for updating DPStore(s)", "Leaf approach")
    plotSort3(T, SortDRunTimeDPSort_mean_list[0], SortDRunTimeDPSort_mean_list[1], SortDRunTimeDPSort_mean_list[2], SortDRunTimeDPSort_mean_list[3], "Privacy parameter $\epsilon$", "Runtime(s)", "Tree-optimized approach -- Update DPStore")

# %%
def plotDP1ApproachNew(T, DPError, TTStore, xlable, ylable, title):
    DPError_mean = np.mean(DPError, axis = 1)
 #   DPStore_mean = np.mean(DPStore, axis = 1)
    TTStore_mean = np.mean(TTStore, axis = 1)
    
    #plt.subplot(1, 1, 1)
 #   y_pos = np.linspace(1, 4, 4, endpoint=True)
    
   # y_points = [y1points, y2points, y3points, y4points]
   # plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
    
   # plt.bar(y_pos +0.20, DPError_mean, width=0.2, label = 'DPCountError')
   # plt.bar(y_pos +0.20*2, DPStore_mean, width=0.2, label = 'DPStoreError')
   # plt.bar(y_pos +0.20*3, TTStore_mean, width=0.2, label = 'TrueRecordError')
    x = [0.25,0.5,1,2]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, DPError_mean, label = 'DPCountError', marker = 'o')
 #   plt.plot(default_x_ticks, DPStore_mean, label = 'DPStoreError', marker = 'o')
    plt.plot(default_x_ticks, TTStore_mean, label = 'TrueRecordError', marker = 'o')
    plt.xticks(default_x_ticks, x)

    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
    plt.legend(loc="upper left", prop={'size': 16})
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q31-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()

    
def plotSort3New(T, eps1, eps2, eps3, eps4, xlable, ylable, title):
    y1points = np.mean(eps1)
    y2points = np.mean(eps2)
    y3points = np.mean(eps3)
    y4points = np.mean(eps4)
    
    #plt.subplot(1, 1, 1)
 #   y_pos = np.linspace(1, 4, 4, endpoint=True)
  #  plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
  #  plt.xticks(y_pos, objects)
    x = [0.25,0.5,1,2]
    y_points = [y1points, y2points, y3points, y4points]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, y_points, marker = 'o')
    plt.xticks(default_x_ticks, x)
    
    plt.xlabel(xlable, fontsize=16)
    plt.ylabel(ylable, fontsize=16)
   # plt.legend(loc="upper right", prop={'size': 14})
    plt.yticks(fontsize=16)
    plt.title(title, fontsize=16)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q31-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()
    
def plotQ31New(T, epsList, N):
    # create file names
    T_string = str(T)+","
    N_string = str(N)
    LeafDPError_mean_list = []
    LeafDPStoreError_mean_list = []
    LeafTTStoreError_mean_list = []
    LeafDPErrorRange_mean_list = []
    LeafDPStoreErrorRange_mean_list = []
    LeafTTStoreErrorRange_mean_list = []
    
    SortDDPError_mean_list = []
    SortDDPStoreError_mean_list = []
    SortDTTStoreError_mean_list = []
    SortDDPErrorRange_mean_list = []
    SortDDPStoreErrorRange_mean_list = []
    SortDTTStoreErrorRange_mean_list = []
    
    LeafDRunTimeDPSort_mean_list = []
    SortDRunTimeDPSort_mean_list = []
    
    for eps in epsList:
        eps_string = str(eps)+","
    #    fileNameLeaf = "leafbin40_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
        fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
        # read files, parse and return mean
 #       returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
        returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
        # point query
        # leaf 
  #      LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
  #      LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
  #      LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
        
  #      LeafDPError_mean_list.append(LeafDPError_mean)
  #      LeafDPStoreError_mean_list.append(LeafDPStoreError_mean)
  #      LeafTTStoreError_mean_list.append(LeafTTStoreError_mean)
        
        # tree_sortD
        SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
        SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
        SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]
        
        SortDDPError_mean_list.append(SortDDPError_mean)
        SortDDPStoreError_mean_list.append(SortDDPStoreError_mean)
        SortDTTStoreError_mean_list.append(SortDTTStoreError_mean)
        
        
        # range query
        # leaf 
  #      LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
  #      LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
  #      LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
        
  #      LeafDPErrorRange_mean_list.append(LeafDPErrorRange_mean)
  #      LeafDPStoreErrorRange_mean_list.append(LeafDPStoreErrorRange_mean)
  #      LeafTTStoreErrorRange_mean_list.append(LeafTTStoreErrorRange_mean)
        
        # tree_sortD
        SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
        SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
        SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]
        
        SortDDPErrorRange_mean_list.append(SortDDPErrorRange_mean)
        SortDDPStoreErrorRange_mean_list.append(SortDDPStoreErrorRange_mean)
        SortDTTStoreErrorRange_mean_list.append(SortDTTStoreErrorRange_mean)
        
        
  #      LeafDRunTimeDPSort_mean = returnedMeanLeaf["metricRunTimeDPSort_mean"]
        SortDRunTimeDPSort_mean = returnedMeanSortD["metricRunTimeDPSort_mean"]
  #      LeafDRunTimeDPSort_mean_list.append(LeafDRunTimeDPSort_mean)
        SortDRunTimeDPSort_mean_list.append(SortDRunTimeDPSort_mean)

        
    # six metrics 
   # title = "T:"+str(T)+"; eps:"+str(eps)+"; N:"+str(N)
    
    title = "Q3"
    
 #   plotDP1Approach(T, LeafDPError_mean_list[0], LeafDPError_mean_list[1], LeafDPError_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafDPStoreError_mean_list[0], LeafDPStoreError_mean_list[1], LeafDPStoreError_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafTTStoreError_mean_list[0], LeafTTStoreError_mean_list[1], LeafTTStoreError_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Point query")
 
 #   plotDP1Approach(T, LeafDPErrorRange_mean_list[0], LeafDPErrorRange_mean_list[1], LeafDPErrorRange_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafDPStoreErrorRange_mean_list[0], LeafDPStoreErrorRange_mean_list[1], LeafDPStoreErrorRange_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafTTStoreErrorRange_mean_list[0], LeafTTStoreErrorRange_mean_list[1], LeafTTStoreErrorRange_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Range query")

    plotDP1ApproachNew(T, SortDDPError_mean_list, SortDTTStoreError_mean_list, "Privacy parameter $\epsilon$", "Errors", "Tree-OPT -- Point query")
   # plotDP1Approach(T, SortDDPStoreError_mean_list[0], SortDDPStoreError_mean_list[1], SortDDPStoreError_mean_list[2], SortDDPStoreError_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDTTStoreError_mean_list[0], SortDTTStoreError_mean_list[1], SortDTTStoreError_mean_list[2], SortDTTStoreError_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Point query")
 
    plotDP1ApproachNew(T, SortDDPErrorRange_mean_list, SortDTTStoreErrorRange_mean_list, "Privacy parameter $\epsilon$", "Errors", "Tree-OPT -- Range query")
   # plotDP1Approach(T, SortDDPStoreErrorRange_mean_list[0], SortDDPStoreErrorRange_mean_list[1], SortDDPStoreErrorRange_mean_list[2], SortDDPStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDTTStoreErrorRange_mean_list[0], SortDTTStoreErrorRange_mean_list[1], SortDTTStoreErrorRange_mean_list[2], SortDTTStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Range query")


#    plotSort3(T, LeafDRunTimeDPSort_mean_list[0], LeafDRunTimeDPSort_mean_list[1], LeafDRunTimeDPSort_mean_list[2], "The number of updates", "Runtime for updating DPStore(s)", "Leaf approach")
    plotSort3New(T, SortDRunTimeDPSort_mean_list[0], SortDRunTimeDPSort_mean_list[1], SortDRunTimeDPSort_mean_list[2], SortDRunTimeDPSort_mean_list[3], "Privacy parameter $\epsilon$", "Runtime(s)", "Tree-OPT -- Update DPStore")

# %%
# Q3-1
# x axis: T
# y axis: sortTime + 3errors
T = 200
epsList = [0.25,0.5,1,2]
N = 1000  # bigger N 1000, 10000
plotQ31New(T, epsList, N)

# %%
def plotDP2Approach(T, DPError, DPStore, TTStore, xlable, ylable, title):
    DPError_mean = np.mean(DPError, axis = 1)
    DPStore_mean = np.mean(DPStore, axis = 1)
    TTStore_mean = np.mean(TTStore, axis = 1)
    
    #plt.subplot(1, 1, 1)
  #  y_pos = np.linspace(1, 2, 2, endpoint=True)
  #  objects = [0.001, 0.01]
   # y_points = [y1points, y2points, y3points, y4points]
   # plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
    
  #  plt.bar(y_pos +0.20, DPError_mean, width=0.2, label = 'DPCountError')
  #  plt.bar(y_pos +0.20*2, DPStore_mean, width=0.2, label = 'DPStoreError')
  #  plt.bar(y_pos +0.20*3, TTStore_mean, width=0.2, label = 'TrueRecordError')

  #  plt.xticks(y_pos, objects)
    
    x = [0.001, 0.01]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, DPError_mean, label = 'DPCountError', marker = 'o')
    plt.plot(default_x_ticks, DPStore_mean, label = 'DPStoreError', marker = 'o')
    plt.plot(default_x_ticks, TTStore_mean, label = 'TrueRecordError', marker = 'o')
    plt.xticks(default_x_ticks, x)
    
    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
    plt.legend(loc="upper left", prop={'size': 14})
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q32-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()

    
def plotSort4(T, eps1, eps2, xlable, ylable, title):
    y1points = np.mean(eps1)
    y2points = np.mean(eps2)
    
    #plt.subplot(1, 1, 1)
   # y_pos = np.linspace(1, 2, 2, endpoint=True)
  #  objects = [0.001, 0.01]
  #  y_points = [y1points, y2points]
  #  plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
  #  plt.xticks(y_pos, objects)
    
    x = [0.001, 0.01]
    y_points = [y1points, y2points]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, y_points, marker = 'o')
    plt.xticks(default_x_ticks, x)
    
    
    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
   # plt.legend(loc="upper right", prop={'size': 14})
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q32-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()
    
def plotQ32(T, pList, N):
    # create file names
    T_string = str(T)+","
    N_string = str(N)
    LeafDPError_mean_list = []
    LeafDPStoreError_mean_list = []
    LeafTTStoreError_mean_list = []
    LeafDPErrorRange_mean_list = []
    LeafDPStoreErrorRange_mean_list = []
    LeafTTStoreErrorRange_mean_list = []
    
    SortDDPError_mean_list = []
    SortDDPStoreError_mean_list = []
    SortDTTStoreError_mean_list = []
    SortDDPErrorRange_mean_list = []
    SortDDPStoreErrorRange_mean_list = []
    SortDTTStoreErrorRange_mean_list = []
    
    LeafDRunTimeDPSort_mean_list = []
    SortDRunTimeDPSort_mean_list = []
    
    for p in pList:
        eps_string = str(1)+","
      #  fileNameLeaf = str(p)+"leafbin40_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
        if p == 0.01:
            fileNameTreeSortD = str(p)+"treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
        else: 
            fileNameTreeSortD = "0.001treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
  
        # read files, parse and return mean
 #       returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
        returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
        # point query
        # leaf 
  #      LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
  #      LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
  #      LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
        
  #      LeafDPError_mean_list.append(LeafDPError_mean)
  #      LeafDPStoreError_mean_list.append(LeafDPStoreError_mean)
  #      LeafTTStoreError_mean_list.append(LeafTTStoreError_mean)
        
        # tree_sortD
        SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
        SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
        SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]
        
        SortDDPError_mean_list.append(SortDDPError_mean)
        SortDDPStoreError_mean_list.append(SortDDPStoreError_mean)
        SortDTTStoreError_mean_list.append(SortDTTStoreError_mean)
        
        
        # range query
        # leaf 
  #      LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
  #      LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
  #      LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
        
  #      LeafDPErrorRange_mean_list.append(LeafDPErrorRange_mean)
  #      LeafDPStoreErrorRange_mean_list.append(LeafDPStoreErrorRange_mean)
  #      LeafTTStoreErrorRange_mean_list.append(LeafTTStoreErrorRange_mean)
        
        # tree_sortD
        SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
        SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
        SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]
        
        SortDDPErrorRange_mean_list.append(SortDDPErrorRange_mean)
        SortDDPStoreErrorRange_mean_list.append(SortDDPStoreErrorRange_mean)
        SortDTTStoreErrorRange_mean_list.append(SortDTTStoreErrorRange_mean)
        
        
  #      LeafDRunTimeDPSort_mean = returnedMeanLeaf["metricRunTimeDPSort_mean"]
        SortDRunTimeDPSort_mean = returnedMeanSortD["metricRunTimeDPSort_mean"]
  #      LeafDRunTimeDPSort_mean_list.append(LeafDRunTimeDPSort_mean)
        SortDRunTimeDPSort_mean_list.append(SortDRunTimeDPSort_mean)

        
    # six metrics 
   # title = "T:"+str(T)+"; eps:"+str(eps)+"; N:"+str(N)
    
    title = "Q3"
    
 #   plotDP1Approach(T, LeafDPError_mean_list[0], LeafDPError_mean_list[1], LeafDPError_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafDPStoreError_mean_list[0], LeafDPStoreError_mean_list[1], LeafDPStoreError_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafTTStoreError_mean_list[0], LeafTTStoreError_mean_list[1], LeafTTStoreError_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Point query")
 
 #   plotDP1Approach(T, LeafDPErrorRange_mean_list[0], LeafDPErrorRange_mean_list[1], LeafDPErrorRange_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafDPStoreErrorRange_mean_list[0], LeafDPStoreErrorRange_mean_list[1], LeafDPStoreErrorRange_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafTTStoreErrorRange_mean_list[0], LeafTTStoreErrorRange_mean_list[1], LeafTTStoreErrorRange_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Range query")

    plotDP2Approach(T, SortDDPError_mean_list, SortDDPStoreError_mean_list, SortDTTStoreError_mean_list, "Parameter p", "Errors", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDDPStoreError_mean_list[0], SortDDPStoreError_mean_list[1], SortDDPStoreError_mean_list[2], SortDDPStoreError_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDTTStoreError_mean_list[0], SortDTTStoreError_mean_list[1], SortDTTStoreError_mean_list[2], SortDTTStoreError_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Point query")
 
    plotDP2Approach(T, SortDDPErrorRange_mean_list, SortDDPStoreErrorRange_mean_list, SortDTTStoreErrorRange_mean_list, "Parameter p", "Errors", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDDPStoreErrorRange_mean_list[0], SortDDPStoreErrorRange_mean_list[1], SortDDPStoreErrorRange_mean_list[2], SortDDPStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDTTStoreErrorRange_mean_list[0], SortDTTStoreErrorRange_mean_list[1], SortDTTStoreErrorRange_mean_list[2], SortDTTStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Range query")


#    plotSort3(T, LeafDRunTimeDPSort_mean_list[0], LeafDRunTimeDPSort_mean_list[1], LeafDRunTimeDPSort_mean_list[2], "The number of updates", "Runtime for updating DPStore(s)", "Leaf approach")
    plotSort4(T, SortDRunTimeDPSort_mean_list[0], SortDRunTimeDPSort_mean_list[1], "Parameter p", "Runtime(s)", "Tree-optimized approach -- Update DPStore")

# %%
# Q3-2
# x axis: T
# y axis: sortTime + 3errors
T = 200
pList = [0.001]#,0.01]
N = 1000  # bigger N 1000, 10000
plotQ32(T, pList, N)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 7
#       5 pList = [0.001]#,0.01]
#       6 N = 1000  # bigger N 1000, 10000
# ----> 7 plotQ32(T, pList, N)
#
# Cell In[24], line 154, in plotQ32(T, pList, N)
#     144    title = "Q3"
#     146 #   plotDP1Approach(T, LeafDPError_mean_list[0], LeafDPError_mean_list[1], LeafDPError_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Point query")
#     147 #   plotDP1Approach(T, LeafDPStoreError_mean_list[0], LeafDPStoreError_mean_list[1], LeafDPStoreError_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Point query")
#     148 #   plotDP1Approach(T, LeafTTStoreError_mean_list[0], LeafTTStoreError_mean_list[1], LeafTTStoreError_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Point query")
#    (...)
#     151 #   plotDP1Approach(T, LeafDPStoreErrorRange_mean_list[0], LeafDPStoreErrorRange_mean_list[1], LeafDPStoreErrorRange_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Range query")
#     152 #   plotDP1Approach(T, LeafTTStoreErrorRange_mean_list[0], LeafTTStoreErrorRange_mean_list[1], LeafTTStoreErrorRange_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Range query")
# --> 154    plotDP2Approach(T, SortDDPError_mean_list, SortDDPStoreError_mean_list, SortDTTStoreError_mean_list, "Parameter p", "Errors", "Tree-optimized approach -- Point query")
#     155   # plotDP1Approach(T, SortDDPStoreError_mean_list[0], SortDDPStoreError_mean_list[1], SortDDPStoreError_mean_list[2], SortDDPStoreError_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Point query")
#     156   # plotDP1Approach(T, SortDTTStoreError_mean_list[0], SortDTTStoreError_mean_list[1], SortDTTStoreError_mean_list[2], SortDTTStoreError_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Point query")
#     158    plotDP2Approach(T, SortDDPErrorRange_mean_list, SortDDPStoreErrorRange_mean_list, SortDTTStoreErrorRange_mean_list, "Parameter p", "Errors", "Tree-optimized approach -- Range query")
#
# Cell In[24], line 20, in plotDP2Approach(T, DPError, DPStore, TTStore, xlable, ylable, title)
#      18 x = [0.001, 0.01]
#      19 default_x_ticks = range(len(x))
# ---> 20 plt.plot(default_x_ticks, DPError_mean, label = 'DPCountError', marker = 'o')
#      21 plt.plot(default_x_ticks, DPStore_mean, label = 'DPStoreError', marker = 'o')
#      22 plt.plot(default_x_ticks, TTStore_mean, label = 'TrueRecordError', marker = 'o')
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (2,) and (1,)

# %%
def plotDP3Approach(T, DPError, DPStore, TTStore, xlable, ylable, title):
    DPError_mean = np.mean(DPError, axis = 1)
    DPStore_mean = np.mean(DPStore, axis = 1)
    TTStore_mean = np.mean(TTStore, axis = 1)
    
    #plt.subplot(1, 1, 1)
  #  y_pos = np.linspace(1, 2, 2, endpoint=True)
  #  objects = [0.001, 0.01]
   # y_points = [y1points, y2points, y3points, y4points]
   # plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
    
  #  plt.bar(y_pos +0.20, DPError_mean, width=0.2, label = 'DPCountError')
  #  plt.bar(y_pos +0.20*2, DPStore_mean, width=0.2, label = 'DPStoreError')
  #  plt.bar(y_pos +0.20*3, TTStore_mean, width=0.2, label = 'TrueRecordError')

  #  plt.xticks(y_pos, objects)
    
    x = [40, 40]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, DPError_mean, label = 'DPCountError', marker = 'o')
    plt.plot(default_x_ticks, DPStore_mean, label = 'DPStoreError', marker = 'o')
    plt.plot(default_x_ticks, TTStore_mean, label = 'TrueRecordError', marker = 'o')
    plt.xticks(default_x_ticks, x)
    
    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
    plt.legend(loc="upper left", prop={'size': 14})
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("plots200-1000/Q32-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()

    
def plotSort5(T, eps1, eps2, xlable, ylable, title):
    y1points = np.mean(eps1)
    y2points = np.mean(eps2)
    
    #plt.subplot(1, 1, 1)
   # y_pos = np.linspace(1, 2, 2, endpoint=True)
  #  objects = [0.001, 0.01]
  #  y_points = [y1points, y2points]
  #  plt.bar(y_pos, y_points, align='center', alpha=0.5, color='g')
  #  plt.xticks(y_pos, objects)
    
    x = [40, 40]
    y_points = [y1points, y2points]
    default_x_ticks = range(len(x))
    plt.plot(default_x_ticks, y_points, marker = 'o')
    plt.xticks(default_x_ticks, x)
    
    
    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
   # plt.legend(loc="upper right", prop={'size': 14})
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("plots200-1000/Q32-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()
    
def plotQ33(T, binList, N):
    # create file names
    T_string = str(T)+","
    N_string = str(N)
    LeafDPError_mean_list = []
    LeafDPStoreError_mean_list = []
    LeafTTStoreError_mean_list = []
    LeafDPErrorRange_mean_list = []
    LeafDPStoreErrorRange_mean_list = []
    LeafTTStoreErrorRange_mean_list = []
    
    SortDDPError_mean_list = []
    SortDDPStoreError_mean_list = []
    SortDTTStoreError_mean_list = []
    SortDDPErrorRange_mean_list = []
    SortDDPStoreErrorRange_mean_list = []
    SortDTTStoreErrorRange_mean_list = []
    
    LeafDRunTimeDPSort_mean_list = []
    SortDRunTimeDPSort_mean_list = []
    
    for bins in binList:
        eps_string = str(1)+","
      #  fileNameLeaf = str(p)+"leafbin40_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
        if bins == 40:
            fileNameTreeSortD = "0.001treebin40_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
        else: 
            fileNameTreeSortD = str(p)+"0.001treebin40_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
  
        # read files, parse and return mean
 #       returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
        returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
        # point query
        # leaf 
  #      LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
  #      LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
  #      LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
        
  #      LeafDPError_mean_list.append(LeafDPError_mean)
  #      LeafDPStoreError_mean_list.append(LeafDPStoreError_mean)
  #      LeafTTStoreError_mean_list.append(LeafTTStoreError_mean)
        
        # tree_sortD
        SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
        SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
        SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]
        
        SortDDPError_mean_list.append(SortDDPError_mean)
        SortDDPStoreError_mean_list.append(SortDDPStoreError_mean)
        SortDTTStoreError_mean_list.append(SortDTTStoreError_mean)
        
        
        # range query
        # leaf 
  #      LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
  #      LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
  #      LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
        
  #      LeafDPErrorRange_mean_list.append(LeafDPErrorRange_mean)
  #      LeafDPStoreErrorRange_mean_list.append(LeafDPStoreErrorRange_mean)
  #      LeafTTStoreErrorRange_mean_list.append(LeafTTStoreErrorRange_mean)
        
        # tree_sortD
        SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
        SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
        SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]
        
        SortDDPErrorRange_mean_list.append(SortDDPErrorRange_mean)
        SortDDPStoreErrorRange_mean_list.append(SortDDPStoreErrorRange_mean)
        SortDTTStoreErrorRange_mean_list.append(SortDTTStoreErrorRange_mean)
        
        
  #      LeafDRunTimeDPSort_mean = returnedMeanLeaf["metricRunTimeDPSort_mean"]
        SortDRunTimeDPSort_mean = returnedMeanSortD["metricRunTimeDPSort_mean"]
  #      LeafDRunTimeDPSort_mean_list.append(LeafDRunTimeDPSort_mean)
        SortDRunTimeDPSort_mean_list.append(SortDRunTimeDPSort_mean)

        
    # six metrics 
   # title = "T:"+str(T)+"; eps:"+str(eps)+"; N:"+str(N)
    
    title = "Q3"
    
 #   plotDP1Approach(T, LeafDPError_mean_list[0], LeafDPError_mean_list[1], LeafDPError_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafDPStoreError_mean_list[0], LeafDPStoreError_mean_list[1], LeafDPStoreError_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Point query")
 #   plotDP1Approach(T, LeafTTStoreError_mean_list[0], LeafTTStoreError_mean_list[1], LeafTTStoreError_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Point query")
 
 #   plotDP1Approach(T, LeafDPErrorRange_mean_list[0], LeafDPErrorRange_mean_list[1], LeafDPErrorRange_mean_list[2], "The number of updates", "DPCountError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafDPStoreErrorRange_mean_list[0], LeafDPStoreErrorRange_mean_list[1], LeafDPStoreErrorRange_mean_list[2], "The number of updates", "DPStoreError", "Leaf aproach -- Range query")
 #   plotDP1Approach(T, LeafTTStoreErrorRange_mean_list[0], LeafTTStoreErrorRange_mean_list[1], LeafTTStoreErrorRange_mean_list[2], "The number of updates", "TTStoreError", "Leaf aproach -- Range query")

    plotDP3Approach(T, SortDDPError_mean_list, SortDDPStoreError_mean_list, SortDTTStoreError_mean_list, "#bins", "Errors", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDDPStoreError_mean_list[0], SortDDPStoreError_mean_list[1], SortDDPStoreError_mean_list[2], SortDDPStoreError_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Point query")
   # plotDP1Approach(T, SortDTTStoreError_mean_list[0], SortDTTStoreError_mean_list[1], SortDTTStoreError_mean_list[2], SortDTTStoreError_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Point query")
 
    plotDP3Approach(T, SortDDPErrorRange_mean_list, SortDDPStoreErrorRange_mean_list, SortDTTStoreErrorRange_mean_list, "#bins", "Errors", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDDPStoreErrorRange_mean_list[0], SortDDPStoreErrorRange_mean_list[1], SortDDPStoreErrorRange_mean_list[2], SortDDPStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "DPStoreError", "Tree-optimized approach -- Range query")
   # plotDP1Approach(T, SortDTTStoreErrorRange_mean_list[0], SortDTTStoreErrorRange_mean_list[1], SortDTTStoreErrorRange_mean_list[2], SortDTTStoreErrorRange_mean_list[3], "Privacy parameter $\epsilon$", "TTStoreError", "Tree-optimized approach -- Range query")


#    plotSort3(T, LeafDRunTimeDPSort_mean_list[0], LeafDRunTimeDPSort_mean_list[1], LeafDRunTimeDPSort_mean_list[2], "The number of updates", "Runtime for updating DPStore(s)", "Leaf approach")
    plotSort5(T, SortDRunTimeDPSort_mean_list[0], SortDRunTimeDPSort_mean_list[1], "#bins", "Runtime(s)", "Tree-optimized approach -- Update DPStore")

# %%
# Q3-3
# x axis: T
# y axis: sortTime + 3errors
T = 200
binList = [40,40]
N = 1000  # bigger N 1000, 10000
plotQ33(T, binList, N)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 7
#       5 binList = [40,40]
#       6 N = 1000  # bigger N 1000, 10000
# ----> 7 plotQ33(T, binList, N)
#
# Cell In[22], line 94, in plotQ33(T, binList, N)
#      90            fileNameTreeSortD = str(p)+"0.001treebin40_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
#      92        # read files, parse and return mean
#      93 #       returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
# ---> 94        returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)
#      95        # point query
#      96        # leaf
#      97  #      LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
#    (...)
#     104
#     105        # tree_sortD
#     106        SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
#
# Cell In[4], line 2, in readFileReturnMeanTree(fileName)
#       1 def readFileReturnMeanTree(fileName):
# ----> 2     with open(fileName) as f:
#       3         lines = f.readlines()
#       4     numPrint = 11
#
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '0.001treebin40_ss1.txt,200,1,1000,2;0.txt'

# %%
def plotSortnew(T, arrayTree_sortA, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, T, T, endpoint=True)
    y2points = arrayTree_sortA
    y3points = arrayTree_sortD
    
    #plt.subplot(1, 1, 1)
    plt.plot(x1points, y2points, 'r.', label="p = 0.01")
    plt.plot(xpoints, y3points, 'g.', label="p = 0.001")

    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
    plt.legend(loc="upper left", prop={'size': 14})
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q33-"+ylable+"-"+title+".pdf", bbox_inches='tight')
    plt.show()
    
def plotQ32new2(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "leafbin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameTreeSortA = "0.01treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
    fileNameTreeSortD = "treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanTreeSortA = readFileReturnMeanTree(fileNameTreeSortA)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)           
            
            
    # six metrics
        #leaf 
    LeafRunTimeDPSort_mean = returnedMeanLeaf["metricRunTimeDPSort_mean"]
  #  LeafCacheNum_mean = data_loaded["list_dummyRecordNumCache_leaf"]
        #tree_sortRoot
    SortRootRunTimeDPSort_mean = returnedMeanTreeSortA["metricRunTimeDPSort_mean"]
  #  SortRootCacheNum_mean = data_loaded["list_dummyRecordNumCache_treeA"]
        #tree_sortD
    SortDRunTimeDPSort_mean = returnedMeanSortD["metricRunTimeDPSort_mean"]
  #  SortDCacheNum_mean = data_loaded["list_dummyRecordNumCache_treeD"]

    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    plotSortnew(T, SortRootRunTimeDPSort_mean, SortDRunTimeDPSort_mean, "The number of updates", "Runtime(s)", title)
  #  plotCache(T, LeafCacheNum_mean, SortRootCacheNum_mean, SortDCacheNum_mean, "time", "numOfDummy", title)


def plotDPSeperate3(T, arrayTree_sortSubroot, arrayTree_sortD, xlable, ylable, title):
    xpoints = np.linspace(1, T, T, endpoint=True)
    x1points = np.linspace(1, T, T, endpoint=True)
   # y1points = arrayLeaf
    y2points = arrayTree_sortSubroot
    y3points = arrayTree_sortD

    #plt.subplot(1, 1, 1)
  #  plt.plot(xpoints, y1points, 'b^', label="Leaf")
    plt.plot(x1points, y2points, 'r.', label="p = 0.01")
    plt.plot(xpoints, y3points, 'g.', label="p = 0.001")

    plt.xlabel(xlable, fontsize=14)
    plt.ylabel(ylable, fontsize=14)
    plt.legend(loc="upper left", prop={'size': 14})
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title(title, fontsize=14)
    title = title.replace("$\epsilon$", "epsilon")
    plt.savefig("nycplots200-1000/Q33-"+ylable+"-"+title+".pdf", bbox_inches='tight')

    plt.show()


    
def plotQ32new(T, eps, N):
    # create file names
    T_string = str(T)+","
    eps_string = str(eps)+","
    N_string = str(N)
    fileNameLeaf = "leafbin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+";2.txt"
    fileNameTreeSortA = "0.01treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"
    fileNameTreeSortD = "treebin40_total_amount_ss1.txt,"+T_string+eps_string+N_string+",2;0.txt"

    # read files, parse and return mean
    returnedMeanLeaf = readFileReturnMeanAll(fileNameLeaf)
    returnedMeanSortA = readFileReturnMeanTree(fileNameTreeSortA)
    returnedMeanSortD = readFileReturnMeanTree(fileNameTreeSortD)    
    
    # six metrics 
    title = "T:"+str(T)+"; $\epsilon$:"+str(eps)+"; N:"+str(N)
    # point query
    # leaf 
    LeafDPError_mean = returnedMeanLeaf["metricDPErrorP_mean"]
    LeafDPStoreError_mean = returnedMeanLeaf["metricDPStoreErrorP_mean"]
    LeafTTStoreError_mean = returnedMeanLeaf["metricTTStoreErrorP_mean"]
    # tree_sortA
    SortADPError_mean = returnedMeanSortA["metricDPErrorP_mean"]
    SortADPStoreError_mean = returnedMeanSortA["metricDPStoreErrorP_mean"]
    SortATTStoreError_mean = returnedMeanSortA["metricTTStoreErrorP_mean"]
    # tree_sortD
    SortDDPError_mean = returnedMeanSortD["metricDPErrorP_mean"]
    SortDDPStoreError_mean = returnedMeanSortD["metricDPStoreErrorP_mean"]
    SortDTTStoreError_mean = returnedMeanSortD["metricTTStoreErrorP_mean"]

    
    plotDPSeperate3(T, SortADPError_mean, SortDDPError_mean, "The number of updates", "DPCountError-PointQuery", title)
    plotDPSeperate3(T, SortATTStoreError_mean, SortDTTStoreError_mean, "The number of updates", "TrueRecordError-PointQuery", title)
    plotDPSeperate3(T, SortADPStoreError_mean, SortDDPStoreError_mean, "The number of updates", "DPStoreError-PointQuery", title)
 
    # range query
    # leaf 
    LeafDPErrorRange_mean = returnedMeanLeaf["metricDPErrorR_mean"]
    LeafDPStoreErrorRange_mean = returnedMeanLeaf["metricDPStoreErrorR_mean"]
    LeafTTStoreErrorRange_mean = returnedMeanLeaf["metricTTStoreErrorR_mean"]
    # tree_sortA
    SortADPErrorRange_mean = returnedMeanSortA["metricDPErrorR_mean"]
    SortADPStoreErrorRange_mean = returnedMeanSortA["metricDPStoreErrorR_mean"]
    SortATTStoreErrorRange_mean = returnedMeanSortA["metricTTStoreErrorR_mean"]
    # tree_sortD
    SortDDPErrorRange_mean = returnedMeanSortD["metricDPErrorR_mean"]
    SortDDPStoreErrorRange_mean = returnedMeanSortD["metricDPStoreErrorR_mean"]
    SortDTTStoreErrorRange_mean = returnedMeanSortD["metricTTStoreErrorR_mean"]

    
    plotDPSeperate3(T, SortADPErrorRange_mean, SortDDPErrorRange_mean, "The number of updates", "DPCountError-RangeQuery", title)
    plotDPSeperate3(T, SortATTStoreErrorRange_mean, SortDTTStoreErrorRange_mean, "The number of updates", "TrueRecordError-RangeQuery", title)
    plotDPSeperate3(T, SortADPStoreErrorRange_mean, SortDDPStoreErrorRange_mean, "The number of updates", "DPStoreError-RangeQuery", title)

# %%
T = 200
eps = 1
N = 1000
plotQ32new2(T, eps, N)
plotQ32new(T, eps, N)

# %%
#
